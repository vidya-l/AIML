# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/content/bank-additional-full.csv")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
##Data preprocessing

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
##EDA
num_cols = df.select_dtypes("number")
for col in num_cols:
  plt.figure(figsize=(12,6))
  plt.subplot(1,2,1)
  plt.title(col)
  sns.distplot(df[col])
  plt.subplot(1,2,2)
  sns.boxplot(df[col])
  plt.show()
#
# Out:
# /tmp/ipykernel_818/1037023791.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# /tmp/ipykernel_818/1037023791.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# /tmp/ipykernel_818/1037023791.py:6: UserWarning:
#
# ...

# %%
#check skeweness
num_cols.skew()
# Out:
# age               0.784560
# duration          3.262808
# campaign          4.762044
# pdays            -4.921386
# previous          3.831396
# emp.var.rate     -0.724061
# cons.price.idx   -0.230853
# cons.conf.idx     0.302876
# euribor3m        -0.709194
# nr.employed      -1.044317
# dtype: float64

# %%
##encode target variable

# %%
df['y'].replace('no', 0, inplace=True)
df['y'].replace('yes', 1, inplace=True)
# Out:
# /tmp/ipykernel_818/361369379.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['y'].replace('no', 0, inplace=True)
# /tmp/ipykernel_818/361369379.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
##encode categorical features
cat_cols = df.select_dtypes("object").columns.tolist()
cat_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
df = pd.get_dummies(df, columns=cat_cols, drop_first=True, dtype=int)

# %%
df
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
df['y'].value_counts() # imbalance is there
# Out:
# y
# 0    36537
# 1     4639
# Name: count, dtype: int64

# %%
36537/4639#smote can be applied
# Out:
# 7.876050873032981

# %%
##split data and train diff models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

X = df.drop(columns=['y'])
y = df['y']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ##Individual models

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_resampled, y_train_resampled)

# Make predictions
logreg_y_pred = logreg.predict(X_test)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, logreg_y_pred))
# Out:
# Accuracy: 0.8800388538125303
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=20)

# Fit the model
knn.fit(X_train_resampled, y_train_resampled)
knn_y_pred = knn.predict(X_test)
knn_y_pred
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,knn_y_pred)
# Out:
# 0.8427634774162215

# %%
from sklearn.tree import DecisionTreeClassifier #knn module?? sklearn.neighbors, logistic regresion - linear model
dt = DecisionTreeClassifier()
dt.fit(X_train_resampled, y_train_resampled)

# Make predictions
dt_y_pred = dt.predict(X_test)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, dt_y_pred))
# Out:
# Accuracy: 0.8828314715881496

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_resampled, y_train_resampled)

# Make predictions
svm_y_pred = svc.predict(X_test)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, svm_y_pred))
# Out:
# Accuracy: 0.8397280233122875

# %% [markdown]
# ##ENSEMBLE MODELS

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train_resampled, y_train_resampled)

# Predict and evaluate
rf_y_pred = rf_model.predict(X_test)
accuracy = accuracy_score(y_test, rf_y_pred)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.90808644973288

# %% [markdown]
# #BAGGING

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier

# Bagging with KKN as base estimator
bag_knn = BaggingClassifier(
    estimator=KNeighborsClassifier(),
    n_estimators=10,
    random_state=42
)
bag_knn.fit(X_train_resampled, y_train_resampled)

bag_knn_y_pred = bag_knn.predict(X_test)

#  Accuracy
print("Bagging with SVC Accuracy:", accuracy_score(y_test, bag_knn_y_pred))
# Out:
# Bagging with SVC Accuracy: 0.8461631860126275

# %%
from sklearn.ensemble import RandomForestClassifier
adaboost_model = RandomForestClassifier()

# Train the model
adaboost_model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set

ada_y_pred = adaboost_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, ada_y_pred)
print(f'Accuracy of AdaBoost: {accuracy:.2f}')
# Out:
# Accuracy of AdaBoost: 0.91

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
# Create a Gradient Boosting model
gradient_boosting_model = GradientBoostingClassifier()

# Train the model
gradient_boosting_model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
gra_y_pred = gradient_boosting_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, gra_y_pred)
print(f'Accuracy of Gradient Boosting: {accuracy:.2f}')
# Out:
# Accuracy of Gradient Boosting: 0.90

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42,
    eval_metric='logloss'
)

xgb.fit(X_train_resampled, y_train_resampled)
xgb_y_pred = xgb.predict(X_test)

print("XGBoost Accuracy:", accuracy_score(y_test, xgb_y_pred))
# Out:
# XGBoost Accuracy: 0.8949732880038854

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

predictions = {
    "Logistic Regression": logreg_y_pred,
    "KNN": knn_y_pred,
    "Decision Tree": dt_y_pred,
    "Random Forest": rf_y_pred,
    "AdaBoost": ada_y_pred,
    "Gradient Boosting": gra_y_pred,
    "XGBoost": xgb_y_pred,
    "Bagging Classifier": bag_knn_y_pred,
    "SVM": svm_y_pred,
}

# Initialize a dictionary to store metrics
results = {
    "Model": [],
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "F1-Score": []
}

# Compute metrics for each model
for model_name, y_pred in predictions.items():
    results["Model"].append(model_name)
    results["Accuracy"].append(accuracy_score(y_test, y_pred))
    results["Precision"].append(precision_score(y_test, y_pred, average='macro'))
    results["Recall"].append(recall_score(y_test, y_pred, average='macro'))
    results["F1-Score"].append(f1_score(y_test, y_pred, average='macro'))

results
# Out:
# {'Model': ['Logistic Regression',
#   'KNN',
#   'Decision Tree',
#   'Random Forest',
#   'AdaBoost',
#   'Gradient Boosting',
#   'XGBoost',
#   'Bagging Classifier',
#   'SVM'],
#  'Accuracy': [0.8800388538125303,
#   0.8427634774162215,
#   0.8828314715881496,
#   0.90808644973288,
#   0.9089363768819816,
#   0.8980087421078193,
#   0.8949732880038854,
#   0.8461631860126275,
#   0.8397280233122875],
#  'Precision': [0.7165921562811195,
#   0.6942598604878131,
#   0.7124482870822294,
#   0.7714508298239338,
#   0.7739593618262448,
#   0.7490248851511014,
#   0.7443216264093769,
#   0.6885105818845961,
#   0.6905533730051532],
#  'Recall': [0.7894088669950738,
#   0.8554238505747127,
#   0.7392412424740011,
#   0.756764846743295,
#   0.7567733990147782,
#   0.8202312534209086,
#   0.8246356732348112,
#   0.8239429392446633,
#   0.849480021893815],
#  'F1-Score': [0.744369008801793,
#   0.7299663038298224,
#   0.7245785347133366,
#   0.7638096571593895,
#   0.7649613139336047,
# ...

# %%
# Convert results to a DataFrame
results_df = pd.DataFrame(results)


# Display the results
print(results_df)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score
# 0  Logistic Regression  0.880039   0.716592  0.789409  0.744369
# 1                  KNN  0.842763   0.694260  0.855424  0.729966
# 2        Decision Tree  0.882831   0.712448  0.739241  0.724579
# 3        Random Forest  0.908086   0.771451  0.756765  0.763810
# 4             AdaBoost  0.908936   0.773959  0.756773  0.764961
# 5    Gradient Boosting  0.898009   0.749025  0.820231  0.777606
# 6              XGBoost  0.894973   0.744322  0.824636  0.775431
# 7   Bagging Classifier  0.846163   0.688511  0.823943  0.722905
# 8                  SVM  0.839728   0.690553  0.849480  0.725271

# %%
# Sort by F1-Score (or any other metric you prefer)
results_df = results_df.sort_values(by="F1-Score",ascending=False)
print(results_df)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score
# 5    Gradient Boosting  0.898009   0.749025  0.820231  0.777606
# 6              XGBoost  0.894973   0.744322  0.824636  0.775431
# 4             AdaBoost  0.908936   0.773959  0.756773  0.764961
# 3        Random Forest  0.908086   0.771451  0.756765  0.763810
# 0  Logistic Regression  0.880039   0.716592  0.789409  0.744369
# 1                  KNN  0.842763   0.694260  0.855424  0.729966
# 8                  SVM  0.839728   0.690553  0.849480  0.725271
# 2        Decision Tree  0.882831   0.712448  0.739241  0.724579
# 7   Bagging Classifier  0.846163   0.688511  0.823943  0.722905

# %% [markdown]
# ##INSIGHTS

# %% [markdown]
# Ensemble models achieved higher accuracy and F1-score compared to individual models.
#
# AdaBoost achieved the highest accuracy (90.89%), slightly outperforming Random Forest.
#
# Gradient Boosting achieved the highest F1-score (77.76%), showing the best balance between precision and recall.

# %% [markdown]
# Based on the evaluation results, Gradient Boosting Classifier is selected as the best-performing model.

# %% [markdown]
# Although AdaBoost achieved the highest accuracy (90.89%), Gradient Boosting achieved the highest F1-score (77.76%) and maintained a strong recall (82.02%).

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_resampled.columns,
    'Importance': xgb.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

feature_importance
# Out:
#                           Feature  Importance
# 9                     nr.employed    0.193423
# 22                 marital_single    0.044083
# 1                        duration    0.042752
# 7                   cons.conf.idx    0.040506
# 31                default_unknown    0.038429
# 37              contact_telephone    0.038212
# 51           poutcome_nonexistent    0.036558
# 49                day_of_week_tue    0.034125
# 5                    emp.var.rate    0.033327
# 48                day_of_week_thu    0.032168
# 47                day_of_week_mon    0.029344
# 50                day_of_week_wed    0.028777
# 26          education_high.school    0.028740
# 43                      month_may    0.027430
# 10                job_blue-collar    0.027422
# 18                 job_technician    0.025202
# 25             education_basic.9y    0.022918
# 21                marital_married    0.021864
# 29    education_university.degree    0.021721
# ...

# %%
##

# %% [markdown]
# ##Features influence customer subscription the most.

# %% [markdown]
# The most important featurees are,
#
# • Number of employees,
#
# • Marital status,
#
# • Last contact duration (in seconds),
#
# • Consumer confidence index,
#
# • Default: Has credit in default (unknown),
#
# • Contact: Contact communication type (telephone),
#
# • Poutcome: Outcome of the previous marketing campaign
# (poutcome_nonexistent),
#
# • Day_of_week: Last contact day of the week(tue,thu,mon,wed)
#
# Emp.var.rate: Employment variation rate,
#
# • Education: Education level(high.school)
#
# • Month: Last contact month of the year
# (May)
#
# Job: Type of job etc

# %% [markdown]
# ##Business Insights

# %% [markdown]
# : How the Bank Can Improve Marketing Campaigns
#
#
# ###Important customer-related features such as:
#
# Number of employees,Marital status (marital_single)
# Job type (job_blue-collar, job_technician)
# Education level influence subscription behavior.
#
# ###Recommendation:
# Create targeted campaigns for different customer groups.
# Customize product messages based on customer profiles.
#
# duration is one of the important predictive features.
#
# ###Insight:
# Customers who engage in longer conversations are more likely to subscribe.
# Improved customer engagement and higher conversion rates.
#
# ###Contact Strategy
#
# Features related to:
#
# Contact method (contact_telephone)
# Contact day (day_of_week)
# Campaign frequency (campaign)
#
# affect customer responses.
#
# ###Recommendation:
#
# Identify the best communication channels.
# Contact customers at the most effective times.
# Avoid repeatedly contacting customers who show low interest.
#
# Business impact: Reduced customer fatigue and improved response rates.
#
# ###Use Previous Campaign Information
#
# Customer history features such as:
#
# Previous campaign outcome (poutcome)
# Number of previous contacts (previous)
# Days since previous contact (pdays)
#
# provide useful information about customer behavior.
#
# ###Recommendation:
#
# Prioritize customers who previously showed interest.
# Design follow-up campaigns for customers who interacted positively before.
# ###Consider Economic Conditions
#
# Features such as:
#
# nr.employed
# emp.var.rate
# cons.conf.idx
# euribor3m
#
# show that economic conditions influence customer decisions.
#
# ###Recommendation:
#
# Adjust campaign timing based on economic conditions.
