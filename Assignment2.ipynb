# %% [markdown]
# ##Numpy

# %%
# Create a NumPy array of shape (5, 5) with random integers between 1 and 50.
import numpy as np
a = np.random.randint(1, 50, size=(5, 5))
a
# Out:
# array([[29, 37, 39, 22, 41],
#        [22, 39, 38, 15, 28],
#        [29, 14, 13,  9, 16],
#        [15,  7, 31, 14,  1],
#        [48, 19, 13, 13, 24]])

# %%
#Find the row with the maximum sum.
total = 0
for row in a:
  if(row.sum() > total):
      total = row.sum()
      max_row = row
print("Row with maximum sum is", max_row, "Sum is", total)
# Out:
# Row with maximum sum is [29 37 39 22 41] Sum is 168

# %%
#o Replace all elements greater than the mean with 0.
mean = a.mean()
print("Mean is", a.mean())
a[a > mean] = 0
print(a)
# Out:
# Mean is 23.04
# [[ 0  0  0 22  0]
#  [22  0  0 15  0]
#  [ 0 14 13  9 16]
#  [15  7  0 14  1]
#  [ 0 19 13 13  0]]

# %%
# Create a NumPy array with numbers from 1 to 20.
# Select every 3rd element starting from the 2nd element and store them in a new array.
array = np.arange(1,20)#array
array[1::3]#starts from second element to end, step by 3
# Out:
# array([ 2,  5,  8, 11, 14, 17])

# %% [markdown]
# ##Pandas

# %%
# Load the dataset Iris data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
data = sns.load_dataset('iris')
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# o Display the first 10 rows and basic statistics.
print(round(data.describe()))
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count         150.0        150.0         150.0        150.0
# mean            6.0          3.0           4.0          1.0
# std             1.0          0.0           2.0          1.0
# min             4.0          2.0           1.0          0.0
# 25%             5.0          3.0           2.0          0.0
# 50%             6.0          3.0           4.0          1.0
# 75%             6.0          3.0           5.0          2.0
# max             8.0          4.0           7.0          2.0

# %%
# o Filter all rows where sepal_length > median and species is "versicolor".
data[(data["sepal_length"] > data["sepal_length"].median()) & (data["species"] == "versicolor")]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# 63           6.1          2.9           4.7          1.4  versicolor
# 65           6.7          3.1           4.4          1.4  versicolor
# 68           6.2          2.2           4.5          1.5  versicolor
# 70           5.9          3.2           4.8          1.8  versicolor
# 71           6.1          2.8           4.0          1.3  versicolor
# ...

# %%
# o Group the data by species and compute the mean petal_length.
data.groupby('species')["petal_length"].mean()
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64

# %%
# Add a new column named petal_ratio = petal_length / petal_width.
data["petal_ratio"] = data["petal_length"] / data["petal_width"]
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# 3       7.500000
# 4       7.000000
# ..           ...
# ...

# %%
# o Find the top 5 rows with the highest petal_ratio.
data.sort_values(by=["petal_ratio"], ascending=False).head(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  petal_ratio
# 9            4.9          3.1           1.5          0.1  setosa         15.0
# 32           5.2          4.1           1.5          0.1  setosa         15.0
# 37           4.9          3.6           1.4          0.1  setosa         14.0
# 12           4.8          3.0           1.4          0.1  setosa         14.0
# 13           4.3          3.0           1.1          0.1  setosa         11.0

# %% [markdown]
# ##Data Visualization

# %%
# 5. Using Matplotlib, create:
#o A histogram of  with 15 bins.
plt.hist(data["sepal_length"], bins=15)
plt.show()

# %%
#o A scatter plot of sepal_length vs petal_length, color-coded by species.
plt.scatter(x=data["sepal_length"], y=data["petal_length"],  c=data["species"].astype("category").cat.codes)
plt.show()

# %%
#Using Seaborn, plot:
# o A pairplot of the entire dataset.
sns.pairplot(data)

# %%
# o A boxplot showing petal_width distribution for each species.
sns.boxplot(data=data, x=data["species"], y=data["petal_width"])
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>
